# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\.anaconda\anaconda\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastapi uvicorn pandas
# Out:
# Collecting fastapiNote: you may need to restart the kernel to use updated packages.
#
#   Downloading fastapi-0.128.0-py3-none-any.whl.metadata (30 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.40.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: pandas in c:\users\hp\.anaconda\anaconda\lib\site-packages (2.2.2)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting pydantic>=2.7.0 (from fastapi)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
#      ---------------------------------------- 0.0/90.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/90.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/90.6 kB ? eta -:--:--
#      ------------------ --------------------- 41.0/90.6 kB ? eta -:--:--
#      ------------------ --------------------- 41.0/90.6 kB ? eta -:--:--
#      ------------------ --------------------- 41.0/90.6 kB ? eta -:--:--
#      ------------------ --------------------- 41.0/90.6 kB ? eta -:--:--
#      ------------------ --------------------- 41.0/90.6 kB ? eta -:--:--
#      ------------------ --------------------- 41.0/90.6 kB ? eta -:--:--
#      ------------------ --------------------- 41.0/90.6 kB ? eta -:--:--
#      ------------------ --------------------- 41.0/90.6 kB ? eta -:--:--
#      ------------------ --------------------- 41.0/90.6 kB ? eta -:--:--
#      ---------------------------------- --- 81.9/90.6 kB 183.3 kB/s eta 0:00:01
#      -------------------------------------- 90.6/90.6 kB 171.3 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from fastapi) (4.11.0)
# Collecting annotated-doc>=0.0.2 (from fastapi)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: click>=7.0 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from uvicorn) (8.1.7)
# Collecting h11>=0.8 (from uvicorn)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: colorama in c:\users\hp\.anaconda\anaconda\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from pydantic>=2.7.0->fastapi) (0.6.0)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.7.0->fastapi)
#   Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-extensions>=4.8.0 (from fastapi)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.7.0->fastapi)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi) (4.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi) (1.3.0)
# Downloading fastapi-0.128.0-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.1 kB ? eta -:--:--
#    ----------------------- ---------------- 61.4/103.1 kB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 61.4/103.1 kB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 61.4/103.1 kB 3.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 61.4/103.1 kB 3.4 MB/s eta 0:00:01
#    -------------------------------------  102.4/103.1 kB 454.0 kB/s eta 0:00:01
#    -------------------------------------- 103.1/103.1 kB 371.4 kB/s eta 0:00:00
# Downloading uvicorn-0.40.0-py3-none-any.whl (68 kB)
#    ---------------------------------------- 0.0/68.5 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/68.5 kB ? eta -:--:--
#    ----------------------------------- ---- 61.4/68.5 kB 544.7 kB/s eta 0:00:01
#    ---------------------------------------- 68.5/68.5 kB 413.2 kB/s eta 0:00:00
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#    ---------------------------------------- 0.0/463.6 kB ? eta -:--:--
#     --------------------------------------- 10.2/463.6 kB ? eta -:--:--
#     --------------------------------------- 10.2/463.6 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/463.6 kB 217.9 kB/s eta 0:00:02
#    ---------- --------------------------- 122.9/463.6 kB 901.1 kB/s eta 0:00:01
#    ----------- -------------------------- 143.4/463.6 kB 853.3 kB/s eta 0:00:01
#    ----------- -------------------------- 143.4/463.6 kB 853.3 kB/s eta 0:00:01
#    ----------- -------------------------- 143.4/463.6 kB 853.3 kB/s eta 0:00:01
#    ----------------------- -------------- 286.7/463.6 kB 803.7 kB/s eta 0:00:01
#    ------------------------------ ------- 368.6/463.6 kB 998.3 kB/s eta 0:00:01
#    ------------------------------ ------- 368.6/463.6 kB 998.3 kB/s eta 0:00:01
#    -------------------------------------  460.8/463.6 kB 930.9 kB/s eta 0:00:01
#    -------------------------------------  460.8/463.6 kB 930.9 kB/s eta 0:00:01
#    -------------------------------------- 463.6/463.6 kB 828.8 kB/s eta 0:00:00
# Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/2.0 MB 10.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/2.0 MB 7.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/2.0 MB 7.5 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.0 MB 3.6 MB/s eta 0:00:01
#    -------------- ------------------------- 0.7/2.0 MB 3.2 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.0 MB 3.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.0 MB 3.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.0 MB 3.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/2.0 MB 2.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/2.0 MB 2.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/2.0 MB 1.7 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.0 MB 1.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.2/2.0 MB 1.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.2/2.0 MB 1.8 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.5/2.0 MB 1.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.5/2.0 MB 1.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.5/2.0 MB 1.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.5/2.0 MB 1.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.5/2.0 MB 1.9 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 1.6 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 1.6 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 1.6 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 1.7/2.0 MB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 1.7/2.0 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 1.7/2.0 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 1.9/2.0 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.4 MB/s eta 0:00:00
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
#    ---------------------------------------- 0.0/74.0 kB ? eta -:--:--
#    ---------------------------------------- 74.0/74.0 kB 2.1 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.6 kB ? eta -:--:--
#    ---------------------------------------- 44.6/44.6 kB 1.1 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-extensions, h11, annotated-doc, uvicorn, typing-inspection, starlette, pydantic-core, pydantic, fastapi
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.14.6
#     Uninstalling pydantic_core-2.14.6:
#       Successfully uninstalled pydantic_core-2.14.6
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.3
#     Uninstalling pydantic-2.5.3:
#       Successfully uninstalled pydantic-2.5.3
# Successfully installed annotated-doc-0.0.4 fastapi-0.128.0 h11-0.16.0 pydantic-2.12.5 pydantic-core-2.41.5 starlette-0.50.0 typing-extensions-4.15.0 typing-inspection-0.4.2 uvicorn-0.40.0

# %%
pip install web3
# Out:
# Collecting web3Note: you may need to restart the kernel to use updated packages.
#
#   Downloading web3-7.14.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting eth-abi>=5.0.1 (from web3)
#   Downloading eth_abi-5.2.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting eth-account>=0.13.6 (from web3)
#   Downloading eth_account-0.13.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting eth-hash>=0.5.1 (from eth-hash[pycryptodome]>=0.5.1->web3)
#   Downloading eth_hash-0.7.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting eth-typing>=5.0.0 (from web3)
#   Downloading eth_typing-5.2.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting eth-utils>=5.0.0 (from web3)
#   Downloading eth_utils-5.3.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting hexbytes>=1.2.0 (from web3)
#   Downloading hexbytes-1.3.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: aiohttp>=3.7.4.post0 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from web3) (3.9.5)
# Requirement already satisfied: pydantic>=2.4.0 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from web3) (2.12.5)
# Requirement already satisfied: pywin32>=223 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from web3) (305.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from web3) (2.32.2)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from web3) (4.15.0)
# Collecting types-requests>=2.0.0 (from web3)
#   Downloading types_requests-2.32.4.20260107-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: websockets<16.0.0,>=10.0.0 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from web3) (15.0.1)
# Collecting pyunormalize>=15.0.0 (from web3)
#   Downloading pyunormalize-17.0.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from aiohttp>=3.7.4.post0->web3) (1.9.3)
# Collecting parsimonious<0.11.0,>=0.10.0 (from eth-abi>=5.0.1->web3)
#   Downloading parsimonious-0.10.0-py3-none-any.whl.metadata (25 kB)
# Collecting bitarray>=2.4.0 (from eth-account>=0.13.6->web3)
#   Downloading bitarray-3.8.0-cp312-cp312-win_amd64.whl.metadata (35 kB)
# Collecting eth-abi>=5.0.1 (from web3)
#   Downloading eth_abi-6.0.0b1-py3-none-any.whl.metadata (3.8 kB)
# Collecting eth-keyfile<0.9.0,>=0.7.0 (from eth-account>=0.13.6->web3)
#   Downloading eth_keyfile-0.8.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting eth-keys>=0.4.0 (from eth-account>=0.13.6->web3)
#   Downloading eth_keys-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting eth-rlp>=2.1.0 (from eth-account>=0.13.6->web3)
#   Downloading eth_rlp-2.2.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting rlp>=1.0.0 (from eth-account>=0.13.6->web3)
#   Downloading rlp-4.1.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting ckzg>=2.0.0 (from eth-account>=0.13.6->web3)
#   Downloading ckzg-2.1.5-cp312-cp312-win_amd64.whl.metadata (930 bytes)
# Collecting pycryptodome<4,>=3.6.6 (from eth-hash[pycryptodome]>=0.5.1->web3)
#   Downloading pycryptodome-3.23.0-cp37-abi3-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: cytoolz>=0.10.1 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from eth-utils>=5.0.0->web3) (0.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from pydantic>=2.4.0->web3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from pydantic>=2.4.0->web3) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from pydantic>=2.4.0->web3) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from requests>=2.23.0->web3) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from requests>=2.23.0->web3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from requests>=2.23.0->web3) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from requests>=2.23.0->web3) (2024.6.2)
# Requirement already satisfied: toolz>=0.8.0 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from cytoolz>=0.10.1->eth-utils>=5.0.0->web3) (0.12.0)
# Requirement already satisfied: regex>=2022.3.15 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from parsimonious<0.11.0,>=0.10.0->eth-abi>=5.0.1->web3) (2023.10.3)
# Downloading web3-7.14.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.4 MB 991.0 kB/s eta 0:00:02
#    - -------------------------------------- 0.1/1.4 MB 1.1 MB/s eta 0:00:02
#    - -------------------------------------- 0.1/1.4 MB 1.1 MB/s eta 0:00:02
#    -- ------------------------------------- 0.1/1.4 MB 357.2 kB/s eta 0:00:04
#    --- ------------------------------------ 0.1/1.4 MB 481.4 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.4 MB 481.4 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.4 MB 481.4 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.4 MB 481.4 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.1/1.4 MB 370.8 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.2/1.4 MB 414.8 kB/s eta 0:00:03
#    ------ --------------------------------- 0.2/1.4 MB 430.1 kB/s eta 0:00:03
#    -------- ------------------------------- 0.3/1.4 MB 473.7 kB/s eta 0:00:03
#    -------- ------------------------------- 0.3/1.4 MB 487.6 kB/s eta 0:00:03
#    --------- ------------------------------ 0.3/1.4 MB 512.0 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.4/1.4 MB 509.8 kB/s eta 0:00:02
#    ----------- ---------------------------- 0.4/1.4 MB 530.1 kB/s eta 0:00:02
#    ------------ --------------------------- 0.4/1.4 MB 550.7 kB/s eta 0:00:02
#    -------------- ------------------------- 0.5/1.4 MB 568.9 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.4 MB 575.3 kB/s eta 0:00:02
#    ---------------- ----------------------- 0.6/1.4 MB 580.2 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.6/1.4 MB 591.8 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.6/1.4 MB 591.8 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.6/1.4 MB 591.8 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.6/1.4 MB 591.8 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.6/1.4 MB 591.8 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.6/1.4 MB 591.8 kB/s eta 0:00:02
#    --------------------- ------------------ 0.7/1.4 MB 552.7 kB/s eta 0:00:02
#    --------------------- ------------------ 0.7/1.4 MB 552.7 kB/s eta 0:00:02
#    --------------------- ------------------ 0.7/1.4 MB 552.7 kB/s eta 0:00:02
#    --------------------- ------------------ 0.7/1.4 MB 524.4 kB/s eta 0:00:02
#    ---------------------- ----------------- 0.8/1.4 MB 521.5 kB/s eta 0:00:02
#    ----------------------- ---------------- 0.8/1.4 MB 520.4 kB/s eta 0:00:02
#    ------------------------ --------------- 0.8/1.4 MB 519.1 kB/s eta 0:00:02
#    ------------------------- -------------- 0.9/1.4 MB 523.0 kB/s eta 0:00:01
#    ------------------------- -------------- 0.9/1.4 MB 526.7 kB/s eta 0:00:01
#    --------------------------- ------------ 0.9/1.4 MB 542.1 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 549.2 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 549.2 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 549.2 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 549.2 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 549.2 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 549.2 kB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 509.2 kB/s eta 0:00:01
#    ------------------------------- -------- 1.1/1.4 MB 530.3 kB/s eta 0:00:01
#    ------------------------------- -------- 1.1/1.4 MB 530.3 kB/s eta 0:00:01
#    ------------------------------- -------- 1.1/1.4 MB 530.3 kB/s eta 0:00:01
#    ------------------------------- -------- 1.1/1.4 MB 530.3 kB/s eta 0:00:01
#    ------------------------------- -------- 1.1/1.4 MB 530.3 kB/s eta 0:00:01
#    ------------------------------- -------- 1.1/1.4 MB 530.3 kB/s eta 0:00:01
#    ------------------------------- -------- 1.1/1.4 MB 530.3 kB/s eta 0:00:01
#    -------------------------------- ------- 1.1/1.4 MB 455.4 kB/s eta 0:00:01
#    ------------------------------------ --- 1.2/1.4 MB 504.2 kB/s eta 0:00:01
#    ------------------------------------ --- 1.3/1.4 MB 509.3 kB/s eta 0:00:01
#    ------------------------------------- -- 1.3/1.4 MB 497.6 kB/s eta 0:00:01
#    ------------------------------------- -- 1.3/1.4 MB 497.6 kB/s eta 0:00:01
#    ------------------------------------- -- 1.3/1.4 MB 491.5 kB/s eta 0:00:01
#    -------------------------------------- - 1.3/1.4 MB 493.5 kB/s eta 0:00:01
#    ---------------------------------------  1.3/1.4 MB 495.4 kB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 494.4 kB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 486.4 kB/s eta 0:00:00
# Downloading eth_abi-5.2.0-py3-none-any.whl (28 kB)
# Downloading eth_account-0.13.7-py3-none-any.whl (587 kB)
#    ---------------------------------------- 0.0/587.5 kB ? eta -:--:--
#    ---- ----------------------------------- 61.4/587.5 kB 1.7 MB/s eta 0:00:01
#    ------- -------------------------------- 112.6/587.5 kB 1.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 174.1/587.5 kB 1.3 MB/s eta 0:00:01
#    ------------- -------------------------- 204.8/587.5 kB 1.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 256.0/587.5 kB 1.1 MB/s eta 0:00:01
#    ------------------- -------------------- 286.7/587.5 kB 1.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 337.9/587.5 kB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------- 389.1/587.5 kB 1.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 430.1/587.5 kB 1.1 MB/s eta 0:00:01
#    -------------------------------- ------- 471.0/587.5 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 512.0/587.5 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 563.2/587.5 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  583.7/587.5 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- 587.5/587.5 kB 947.8 kB/s eta 0:00:00
# Downloading eth_hash-0.7.1-py3-none-any.whl (8.0 kB)
# Downloading eth_typing-5.2.1-py3-none-any.whl (19 kB)
# Downloading eth_utils-5.3.1-py3-none-any.whl (102 kB)
#    ---------------------------------------- 0.0/102.5 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/102.5 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/102.5 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/102.5 kB ? eta -:--:--
#    -------------------------------------  102.4/102.5 kB 535.8 kB/s eta 0:00:01
#    -------------------------------------  102.4/102.5 kB 535.8 kB/s eta 0:00:01
#    -------------------------------------- 102.5/102.5 kB 421.4 kB/s eta 0:00:00
# Downloading hexbytes-1.3.1-py3-none-any.whl (5.1 kB)
# Downloading pyunormalize-17.0.0-py3-none-any.whl (51 kB)
#    ---------------------------------------- 0.0/51.4 kB ? eta -:--:--
#    ---------------------------------------  51.2/51.4 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 51.4/51.4 kB 437.4 kB/s eta 0:00:00
# Downloading types_requests-2.32.4.20260107-py3-none-any.whl (20 kB)
# Downloading bitarray-3.8.0-cp312-cp312-win_amd64.whl (149 kB)
#    ---------------------------------------- 0.0/150.0 kB ? eta -:--:--
#    ---------------- ----------------------- 61.4/150.0 kB 1.6 MB/s eta 0:00:01
#    -------------------------------- ------- 122.9/150.0 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 143.4/150.0 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- 150.0/150.0 kB 890.0 kB/s eta 0:00:00
# Downloading ckzg-2.1.5-cp312-cp312-win_amd64.whl (100 kB)
#    ---------------------------------------- 0.0/101.0 kB ? eta -:--:--
#    ---------------------------- ----------- 71.7/101.0 kB 2.0 MB/s eta 0:00:01
#    -------------------------------------- 101.0/101.0 kB 965.4 kB/s eta 0:00:00
# Downloading eth_keyfile-0.8.1-py3-none-any.whl (7.5 kB)
# Downloading eth_keys-0.7.0-py3-none-any.whl (20 kB)
# Downloading eth_rlp-2.2.0-py3-none-any.whl (4.4 kB)
# Downloading parsimonious-0.10.0-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.4 kB ? eta -:--:--
#    --------------------------------- ------ 41.0/48.4 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 48.4/48.4 kB 606.1 kB/s eta 0:00:00
# Downloading pycryptodome-3.23.0-cp37-abi3-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.8 MB 991.0 kB/s eta 0:00:02
#    -- ------------------------------------- 0.1/1.8 MB 1.3 MB/s eta 0:00:02
#    --- ------------------------------------ 0.2/1.8 MB 1.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.8 MB 1.4 MB/s eta 0:00:02
#    ------ --------------------------------- 0.3/1.8 MB 1.3 MB/s eta 0:00:02
#    ------- -------------------------------- 0.3/1.8 MB 1.3 MB/s eta 0:00:02
#    --------- ------------------------------ 0.4/1.8 MB 1.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/1.8 MB 1.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.5/1.8 MB 1.3 MB/s eta 0:00:01
#    ------------ --------------------------- 0.6/1.8 MB 1.3 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.8 MB 1.2 MB/s eta 0:00:01
#    -------------- ------------------------- 0.7/1.8 MB 1.2 MB/s eta 0:00:01
#    -------------- ------------------------- 0.7/1.8 MB 1.2 MB/s eta 0:00:01
#    -------------- ------------------------- 0.7/1.8 MB 1.2 MB/s eta 0:00:01
#    -------------- ------------------------- 0.7/1.8 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 1.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 0.8/1.8 MB 1.0 MB/s eta 0:00:01
#    ------------------- -------------------- 0.9/1.8 MB 1.1 MB/s eta 0:00:01
#    ------------------- -------------------- 0.9/1.8 MB 1.0 MB/s eta 0:00:01
#    ------------------- -------------------- 0.9/1.8 MB 1.0 MB/s eta 0:00:01
#    ------------------- -------------------- 0.9/1.8 MB 1.0 MB/s eta 0:00:01
#    ------------------- -------------------- 0.9/1.8 MB 894.0 kB/s eta 0:00:02
#    ------------------- -------------------- 0.9/1.8 MB 894.0 kB/s eta 0:00:02
#    -------------------- ------------------- 0.9/1.8 MB 860.7 kB/s eta 0:00:02
#    -------------------- ------------------- 0.9/1.8 MB 842.4 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.0/1.8 MB 868.1 kB/s eta 0:00:01
#    ------------------------ --------------- 1.1/1.8 MB 910.8 kB/s eta 0:00:01
#    -------------------------- ------------- 1.2/1.8 MB 957.6 kB/s eta 0:00:01
#    -------------------------- ------------- 1.2/1.8 MB 919.3 kB/s eta 0:00:01
#    -------------------------- ------------- 1.2/1.8 MB 912.5 kB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.8 MB 898.1 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.8 MB 888.0 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 873.8 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 869.5 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 869.5 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 869.5 kB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 810.0 kB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 810.0 kB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 810.0 kB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 810.0 kB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 810.0 kB/s eta 0:00:01
#    -------------------------------- ------- 1.5/1.8 MB 751.2 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.5/1.8 MB 781.2 kB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.8 MB 815.1 kB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.8 MB 815.1 kB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.8 MB 782.4 kB/s eta 0:00:01
#    ------------------------------------ --- 1.7/1.8 MB 770.0 kB/s eta 0:00:01
#    -------------------------------------- - 1.7/1.8 MB 776.9 kB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 778.2 kB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 771.2 kB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 770.3 kB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 753.4 kB/s eta 0:00:00
# Downloading rlp-4.1.0-py3-none-any.whl (19 kB)
# Installing collected packages: ckzg, bitarray, types-requests, pyunormalize, pycryptodome, parsimonious, hexbytes, eth-typing, eth-hash, eth-utils, rlp, eth-keys, eth-abi, eth-rlp, eth-keyfile, eth-account, web3
# Successfully installed bitarray-3.8.0 ckzg-2.1.5 eth-abi-5.2.0 eth-account-0.13.7 eth-hash-0.7.1 eth-keyfile-0.8.1 eth-keys-0.7.0 eth-rlp-2.2.0 eth-typing-5.2.1 eth-utils-5.3.1 hexbytes-1.3.1 parsimonious-0.10.0 pycryptodome-3.23.0 pyunormalize-17.0.0 rlp-4.1.0 types-requests-2.32.4.20260107 web3-7.14.0

# %%
import fastapi as fi
import uvicorn as un
import pandas as pd
import numpy as np
import requests as rs
from bs4 import BeautifulSoup
import sklearn as skl
from web3 import Web3

# %% [markdown]
# ### Pydantic Models

# %%
from pydantic import BaseModel
from typing import List, Any


class PredictRequest(BaseModel):
    symbol: str


class ScrapeRequest(BaseModel):
    url: str


class BalanceRequest(BaseModel):
    address: str


class RiskRequest(BaseModel):
    symbol: str
    data: List[float]

# %% [markdown]
# ### ML Stub

# %%
import random


def predict_price(symbol: str) -> float:
    base_prices = {
        "BTC": 65000,
        "ETH": 3500,
        "SOL": 150
    }

    base = base_prices.get(symbol.upper(), 100)
    noise = random.uniform(-0.05, 0.05)

    return round(base * (1 + noise), 2)

# %%
import pandas as pd


def aggregate_metrics():
    data = {
        "volume": [120, 340, 560],
        "transactions": [50, 80, 130],
    }

    df = pd.DataFrame(data)

    return {
        "total_volume": int(df["volume"].sum()),
        "avg_transactions": float(df["transactions"].mean()),
    }

# %%
import requests
from bs4 import BeautifulSoup


def scrape_page(https://www.cryptoskope.xyz/: str):
    response = requests.get(https://www.cryptoskope.xyz/, timeout=10)
    soup = BeautifulSoup(response.text, "html.parser")

    title = soup.title.string if soup.title else "No title"
    links = len(soup.find_all("a"))

    return {
        "title": title,
        "link_count": links
    }

# %%
from web3 import Web3

# Example using public Ethereum RPC 
w3 = Web3(Web3.HTTPProvider("https://rpc.ankr.com/eth"))


def get_balance(address: str):
    balance_wei = w3.eth.get_balance(address)
    balance_eth = w3.from_wei(balance_wei, "ether")

    return float(balance_eth)

# %%
import numpy as np


def calculate_risk(symbol: str, data: list[float]) -> float:
    volatility = np.std(data)
    risk_score = min(volatility * 10, 100)

    return round(float(risk_score), 2)

# %% [markdown]
# ### FastAPI

# %%
# !pip install schemas 


from fastapi import FastAPI, HTTPException
from fastapi.middleware.cors import CORSMiddleware

from api_schemas import (
    PredictRequest,
    ScrapeRequest,
    BalanceRequest,
    RiskRequest
)

from services.predictor import predict_price
from services.aggregator import aggregate_metrics
from services.scraper import scrape_page
from services.blockchain import get_balance
from services.risk import calculate_risk


app = FastAPI(title="CryptoSkope Python Service")

base_url ="https://www.cryptoskope.xyz/"

app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],  # tighten in production
    allow_methods=["*"],
    allow_headers=["*"],
)


@app.post("/predict")
def predict(req: PredictRequest):
    price = predict_price(req.symbol)
    return {"symbol": req.symbol, "predicted_price": price}


@app.get("/aggregate")
def aggregate():
    return aggregate_metrics()


@app.post("/scrape")
def scrape(req: ScrapeRequest):
    try:
        return scrape_page(req.base_url)
    except Exception as e:
        raise HTTPException(status_code=400, detail=str(e))


@app.post("/blockchain/balance")
def balance(req: BalanceRequest):
    try:
        balance = get_balance(req.address)
        return {"address": req.address, "balance": balance}
    except Exception as e:
        raise HTTPException(status_code=400, detail=str(e))


@app.post("/risk")
def risk(req: RiskRequest):
    score = calculate_risk(req.symbol, req.data)
    return {"symbol": req.symbol, "risk_score": score}
# Out:
# Requirement already satisfied: schemas in c:\users\hp\.anaconda\anaconda\lib\site-packages (0.7.1)
# Requirement already satisfied: functions in c:\users\hp\.anaconda\anaconda\lib\site-packages (from schemas) (0.7.0)
# Requirement already satisfied: pytest in c:\users\hp\.anaconda\anaconda\lib\site-packages (from schemas) (7.4.4)
# Requirement already satisfied: iniconfig in c:\users\hp\.anaconda\anaconda\lib\site-packages (from pytest->schemas) (1.1.1)
# Requirement already satisfied: packaging in c:\users\hp\.anaconda\anaconda\lib\site-packages (from pytest->schemas) (23.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\hp\.anaconda\anaconda\lib\site-packages (from pytest->schemas) (1.0.0)
# Requirement already satisfied: colorama in c:\users\hp\.anaconda\anaconda\lib\site-packages (from pytest->schemas) (0.4.6)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       4 from fastapi import FastAPI, HTTPException
#       5 from fastapi.middleware.cors import CORSMiddleware
# ----> 7 from api_schemas import (
#       8     PredictRequest,
#       9     ScrapeRequest,
#      10     BalanceRequest,
#      11     RiskRequest
#      12 )
#      14 from services.predictor import predict_price
#      15 from services.aggregator import aggregate_metrics
#
# ModuleNotFoundError: No module named 'api_schemas'
